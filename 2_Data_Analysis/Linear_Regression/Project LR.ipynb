# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/nbattula@gmu.edu/df1_sample.csv")

# %%
import pyspark
import numpy as np
import pandas as pd
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import (VectorAssembler, VectorIndexer)
from pyspark.sql.types import IntegerType

# %%
df1.show(5,True)
df1.printSchema()
# Out:
# +--------+-----+--------------------+-------+-------------------+----+------+--------+----+-----+---+-----------+
# |     _c0|SPEED|          DATA_AS_OF|LINK_ID|        NewDateTime|hour|minute| weekday|year|month|day|day_of_year|
# +--------+-----+--------------------+-------+-------------------+----+------+--------+----+-----+---+-----------+
# |45513578|  0.0|09/15/2018 11:08:...|4616210|2018-09-15 23:08:33|  23|     8|Saturday|2018|    9| 15|        258|
# |41054469|41.63|05/26/2018 10:08:...|4616204|2018-05-26 22:08:04|  22|     8|Saturday|2018|    5| 26|        146|
# |15387406| 9.94|12/27/2020 11:47:...|4763652|2020-12-27 11:47:04|  11|    47|  Sunday|2020|   12| 27|        362|
# |42686070|32.31|07/06/2018 01:18:...|4362252|2018-07-06 13:18:06|  13|    18|  Friday|2018|    7|  6|        187|
# |20714662|52.81|06/07/2021 01:39:...|4616197|2021-06-07 01:39:11|   1|    39|  Monday|2021|    6|  7|        158|
# ...

# %%
df2 = df1.withColumn("hour", df1["hour"].cast('integer'))

# %%
df3 = df1.select(
  [df1.cast(IntegerType())
   .alias() for c in df1.columns]
)
course_df5.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df2.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- SPEED: string (nullable = true)
#  |-- DATA_AS_OF: string (nullable = true)
#  |-- LINK_ID: string (nullable = true)
#  |-- NewDateTime: string (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: string (nullable = true)
#  |-- weekday: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- day_of_year: string (nullable = true)

# %%
from pyspark.sql.types import (
    StringType, IntegerType, FloatType, DateType
)
  
coltype_map = {
    "_c0": StringType(),
    "SPEED": FloatType(),
    "DATA_AS_OF": DateType(),
    "LINK_ID": StringType(),
    "NewDateTime": DateType(),
    "hour": IntegerType(),
    "minute": IntegerType(),
    "weekday": StringType(),
    "year": IntegerType(),
    "month": IntegerType(),
    "day": IntegerType(),
    "day_of_year": IntegerType(),
}
  
# course_df6 has all the column
# types as string
df3 = df2.select(
    [df3.cast(coltype_map)
     #[df3.cast(df3)
     .alias(c) for c in df2.columns]
)
df3.printSchema()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-3808700072418301> in <module>
#      21 # types as string
#      22 df3 = df2.select(
# ---> 23     [df3.cast(coltype_map)
#      24      #[df3.cast(df3)
#      25      .alias(c) for c in df2.columns]
#
# <command-3808700072418301> in <listcomp>(.0)
#      21 # types as string
#      22 df3 = df2.select(
# ---> 23     [df3.cast(coltype_map)
#      24      #[df3.cast(df3)
#      25      .alias(c) for c in df2.columns]
#
# AttributeError: 'dict' object has no attribute 'cast'

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
